# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\Kriti Kapoor\OneDrive\Documents\GitHub\NLP_W2022\Datasets\SBIC.v2.agg.trn.csv') 

df = df[df.whoTarget.notna()]
#len(df.targetMinority.unique())
#df = df[df.targetMinority != '[]']
df.drop('dataSource', inplace=True, axis=1)
df.drop('offensiveYN', inplace=True, axis=1)
df.drop('sexYN', inplace=True, axis=1)
df.drop('targetStereotype', inplace=True, axis=1)

# %%
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
df['sentence'] = df['post']
df['sentence'] = df['sentence'].apply(lambda x: " ".join(x.lower() for x in x.split() if (x not in stop)))
df['sentence'] = df['sentence'].str.replace('[0-9]','')
df['sentence'] = df['sentence'].str.replace('@[\w]+','')
df['sentence'] = df['sentence'].str.replace('[^\w\s]','')
df['sentence'] = df['sentence'].str.replace(' rt ','')
df['sentence'] = df['sentence'].str.replace('[\n]','')
# Out:
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\3774753205.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sentence'] = df['sentence'].str.replace('[0-9]','')
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\3774753205.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sentence'] = df['sentence'].str.replace('@[\w]+','')
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\3774753205.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sentence'] = df['sentence'].str.replace('[^\w\s]','')
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\3774753205.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sentence'] = df['sentence'].str.replace('[\n]','')

# %%
# from nltk.stem import PorterStemmer

# stemmer = PorterStemmer()
# def stem_sentences(sentence):
#      tokens = sentence.split()
#      stemmed_tokens = [stemmer.stem(token) for token in tokens]
#      return ' '.join(stemmed_tokens)
# df['sentence'] = df['sentence'].apply(stem_sentences)

# %%
df.drop('post', inplace=True, axis=1)
df.drop('whoTarget', inplace=True, axis=1)
df.drop('intentYN', inplace=True, axis=1)
df.drop('hasBiasedImplication', inplace=True, axis=1)
df.head()
# Out:
#    Unnamed: 0                                     targetMinority  \
# 0           0                                                 []
# 2           2                                       ["liberals"]
# 3           3                                                 []
# 6           6                                                 []
# 8           8  ["middle eastern folks", "muslim folks", "musl...
#
#   targetCategory                                           sentence
# 0             []     bill kristol ben shaprio two turds toilet bowl
# 2     ["social"]  charlie kirk johnny depp calls death trump  le...
# 3             []  david knight notice quickly things turned bad ...
# 6             []  if family a went  month vacation family m move...
# 8    ["culture"]  just watched facial recognition technology chi...

# %%
df.targetCategory = df.targetCategory.replace('"','', regex=True)
df.targetMinority = df.targetMinority.replace('"','', regex=True)
category = ['social','culture','race']
new_list=[]
newDf = pd.DataFrame(columns=df.columns)
df['targetCategory'] =  df['targetCategory'].apply(lambda x:x.replace('[','').replace(']',''))
df['targetMinority'] =  df['targetMinority'].apply(lambda x:x.replace('[','').replace(']','').lower())

for x in category:
    for item in df.targetCategory:
        if x in item:
            if item not in new_list:
              new_list.append(item)
newcol=[]
for item in df.targetCategory:
    if item in new_list:
     newcol.append(1)
    else:
        newcol.append(0)
df['newcol']=newcol
df = df[df.newcol == 1]
df.drop('newcol', inplace=True, axis=1)
df
# Out:
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\637802110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.targetCategory = df.targetCategory.replace('"','', regex=True)
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\637802110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.targetMinority = df.targetMinority.replace('"','', regex=True)
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\637802110.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['targetCategory'] =  df['targetCategory'].apply(lambda x:x.replace('[','').replace(']',''))
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\637802110.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['targetMinority'] =  df['targetMinority'].apply(lambda x:x.replace('[','').replace(']','').lower())
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\637802110.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['newcol']=newcol
#        Unnamed: 0                                     targetMinority  \
# 2               2                                           liberals
# 8               8  middle eastern folks, muslim folks, muslim fol...
# 20             20                                  immigrants, women
# 23             23                                           liberals
# 26             26                                           liberals
# ...           ...                                                ...
# 35359       35438                                     japanese folks
# 35373       35452                                      conservatives
# 35385       35464                         arabic folks, muslim folks
# 35418       35497                                       muslim folks
# 35423       35503                                         immigrants
#
#         targetCategory                                           sentence
# 2               social  charlie kirk johnny depp calls death trump  le...
# 8              culture  just watched facial recognition technology chi...
# 20     culture, gender  i propose new law any congressman woman votes ...
# 23              social  just partial list dem playbook  getting mornin...
# 26              social  liberals saying get rid guns talking liberals ...
# ...                ...                                                ...
# 35359          culture         look theres fireworks hiroshima world war
# 35373           social  voting trumpbrexit protest vote no wasnt fucki...
# 35385          culture  you da bomb no da bomb in america  compliment ...
# 35418          culture
# 35423          culture  breaking illegal alien x deported  felonies fo...
#
# [3063 rows x 4 columns]

# %%
df.targetCategory = df.targetCategory.str.replace('race','racial')

# %%
import itertools
liberal = ['antifa', 'liberal', 'anti-fa', 'antifascist', 'democrat', 'feminist', 'globalist', 'hilary clinton', 'left', 'socialist', 'social']
conservative = ['alt-right', 'conservative', 'libertarian', 'pro-life', 'republican', 'trump']

political = itertools.chain(liberal,conservative)
political = list(political)

political_list=[]
for x in political:
     for item in df.targetMinority:
        if x in item:
            if item not in political_list:
              political_list.append(item)
tempcol=[]
for item in df.targetMinority:
    if item in political_list:
     tempcol.append(1)
    else:
        tempcol.append(0)
df['tempcol']=tempcol
politicaldf = df[df.tempcol == 1]
politicaldf.drop('tempcol', inplace=True, axis=1)
df.drop('tempcol', inplace=True, axis=1)
politicaldf
# Out:
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\1028785713.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   politicaldf.drop('tempcol', inplace=True, axis=1)
#        Unnamed: 0                                 targetMinority  \
# 2               2                                       liberals
# 23             23                                       liberals
# 26             26                                       liberals
# 28             28                                       liberals
# 50             50                                       liberals
# ...           ...                                            ...
# 34827       34902  conservatives, genocide victims, jewish folks
# 35044       35120                         asian folks, feminists
# 35045       35121                                      feminists
# 35228       35304                                  conservatives
# 35373       35452                                  conservatives
#
#                 targetCategory  \
# 2                       social
# 23                      social
# 26                      social
# 28                      social
# 50                      social
# ...                        ...
# 34827  culture, social, victim
# 35044           racial, social
# 35045                   social
# 35228                   social
# 35373                   social
#
#                                                 sentence  newcol
# 2      charlie kirk johnny depp calls death trump  le...       1
# 23     just partial list dem playbook  getting mornin...       1
# 26     liberals saying get rid guns talking liberals ...       1
# 28     the poverty income inequality the lefts answer...       1
# 50                          thats gets fucking liberal         1
# ...                                                  ...     ...
# 34827  one two hitler s punchline  make germany great...       1
# 35044  sumo wrestlers shave legs  nobody mistakes fem...       1
# 35045  sumo wrestlers shave legs  people nt confuse f...       1
# 35228  re mamma s stupid  repeat  number  mamma s stu...       1
# 35373  voting trumpbrexit protest vote no wasnt fucki...       1
#
# [432 rows x 5 columns]

# %%
import itertools
racial = ['afghan', 'africa', 'asia', 'ethipioa', 'etheopia', 'east', 'black', 'white', 'europ', 'exotic', 'arab', 'refugees', 'japan', 'bangladesh', 'belgian', 'brown', 'east', 'chinese', 'egypt', 'foreign', 'kenya', 'korea', 'mexican', 'nigerian', 'nordic',
'polish', 'puerto', 'slavic', 'somali', 'swedish', 'russian', 'syrian', 'welsh', 'texan', 'thai', 'turkish', 'india', 'irish', 'iran', 'pakistan'
]
religious = ['muslim', 'hindu', 'islam', 'jewish', 'christian', 'jehovah', 'atheist', 'catholic', 'religious', 'religion', 'jew', 'kurd', 'buddhist', 'hebrew', 'mormon', 'scientologists', 'shia']


stereotypical = itertools.chain(racial,religious)
stereotypical = list(stereotypical)

stereotype_list = []
for x in stereotypical:
     for item in df.targetMinority:
        if x in item:
            if item not in stereotype_list:
              stereotype_list.append(item)
tempcol.clear()
for item in df.targetMinority:
     if item in stereotype_list:
      tempcol.append(2)
     else:
        tempcol.append(0)

df['tempcol'] = tempcol
stereotypicaldf = df[df.tempcol == 2]
stereotypicaldf.drop('tempcol', inplace=True, axis=1)
df.drop('tempcol', inplace=True, axis=1)
stereotypicaldf
# Out:
# C:\Users\Kriti Kapoor\AppData\Local\Temp\ipykernel_19620\2853548330.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stereotypicaldf.drop('tempcol', inplace=True, axis=1)
#        Unnamed: 0                                     targetMinority  \
# 8               8  middle eastern folks, muslim folks, muslim fol...
# 487           487                                       jewish folks
# 642           642                                    syrian, syrians
# 643           643                                       jewish folks
# 697           697                                       muslim folks
# ...           ...                                                ...
# 35266       35342                                       muslim folks
# 35281       35357                                   blm, black folks
# 35359       35438                                     japanese folks
# 35385       35464                         arabic folks, muslim folks
# 35418       35497                                       muslim folks
#
#        targetCategory                                           sentence
# 8             culture  just watched facial recognition technology chi...
# 487           culture   ha doubt could anything stupid fucking jew he...
# 642           culture  before pray for syria fake crisis pray for chi...
# 643           culture  beholden israel aipac even running office  on ...
# 697           culture  european governments sentencing citizens death...
# ...               ...                                                ...
# 35266         culture  know say muhammad ali floats like butterfly st...
# 35281  racial, social                wanna hear joke  black lives matter
# 35359         culture         look theres fireworks hiroshima world war
# 35385         culture  you da bomb no da bomb in america  compliment ...
# 35418         culture
#
# [2204 rows x 4 columns]

# %%
#np.unique(df.targetMinority[df.targetCategory=='culture'])
#df[df.targetMinority == 'globalists']
