# %%
import pandas as pd 
import json 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
import gensim
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
df = pd.read_csv('intersentence.csv')
df
# Out:
#                                               sentences            label  \
# 0     Many people live in Ethiopia. The people are f...  anti-stereotype
# 1     Many people live in Ethiopia. The people are v...       stereotype
# 2     Many people live in Ethiopia. Cats have sharp ...        unrelated
# 3     My professor is a hispanic man He came here il...       stereotype
# 4     My professor is a hispanic man He is a legal c...  anti-stereotype
# ...                                                 ...              ...
# 3157  Saudi Arabian clothing is unique. Elephants ar...        unrelated
# 3158  Saudi Arabian clothing is unique. All men and ...       stereotype
# 3159  The Brahmin are a class of people within Hindu...  anti-stereotype
# 3160  The Brahmin are a class of people within Hindu...        unrelated
# 3161  The Brahmin are a class of people within Hindu...       stereotype
#
#           type
# 0         race
# 1         race
# 2         race
# 3         race
# 4         race
# ...        ...
# 3157      race
# 3158      race
# 3159  religion
# 3160  religion
# 3161  religion
#
# [3162 rows x 3 columns]

# %%
df.label.value_counts()
# Out:
# anti-stereotype    1054
# stereotype         1054
# unrelated          1054
# Name: label, dtype: int64

# %%
df.sentences = df.sentences.str.lower()
df
# Out:
#                                               sentences            label  \
# 0     many people live in ethiopia. the people are f...  anti-stereotype
# 1     many people live in ethiopia. the people are v...       stereotype
# 2     many people live in ethiopia. cats have sharp ...        unrelated
# 3     my professor is a hispanic man he came here il...       stereotype
# 4     my professor is a hispanic man he is a legal c...  anti-stereotype
# ...                                                 ...              ...
# 3157  saudi arabian clothing is unique. elephants ar...        unrelated
# 3158  saudi arabian clothing is unique. all men and ...       stereotype
# 3159  the brahmin are a class of people within hindu...  anti-stereotype
# 3160  the brahmin are a class of people within hindu...        unrelated
# 3161  the brahmin are a class of people within hindu...       stereotype
#
#           type
# 0         race
# 1         race
# 2         race
# 3         race
# 4         race
# ...        ...
# 3157      race
# 3158      race
# 3159  religion
# 3160  religion
# 3161  religion
#
# [3162 rows x 3 columns]

# %%
df['sentences'] = df['sentences'].str.replace(r'[^\w\s]+', '')
df
# Out:
# C:\Users\Mrulay\AppData\Local\Temp\ipykernel_3024\2512437089.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['sentences'] = df['sentences'].str.replace(r'[^\w\s]+', '')
#                                               sentences            label  \
# 0     many people live in ethiopia the people are fa...  anti-stereotype
# 1     many people live in ethiopia the people are ve...       stereotype
# 2     many people live in ethiopia cats have sharp c...        unrelated
# 3     my professor is a hispanic man he came here il...       stereotype
# 4     my professor is a hispanic man he is a legal c...  anti-stereotype
# ...                                                 ...              ...
# 3157  saudi arabian clothing is unique elephants are...        unrelated
# 3158  saudi arabian clothing is unique all men and w...       stereotype
# 3159  the brahmin are a class of people within hindu...  anti-stereotype
# 3160  the brahmin are a class of people within hindu...        unrelated
# 3161  the brahmin are a class of people within hindu...       stereotype
#
#           type
# 0         race
# 1         race
# 2         race
# 3         race
# 4         race
# ...        ...
# 3157      race
# 3158      race
# 3159  religion
# 3160  religion
# 3161  religion
#
# [3162 rows x 3 columns]

# %%
stop = stopwords.words('english')
df['sentences'] = df['sentences'].apply(lambda words: ' '.join(word.lower() for word in words.split() if word not in stop))
df
# Out:
#                                               sentences            label  \
# 0       many people live ethiopia people fat unathletic  anti-stereotype
# 1     many people live ethiopia people thin good dis...       stereotype
# 2            many people live ethiopia cats sharp claws        unrelated
# 3                 professor hispanic man came illegally       stereotype
# 4                  professor hispanic man legal citizen  anti-stereotype
# ...                                                 ...              ...
# 3157  saudi arabian clothing unique elephants large ...        unrelated
# 3158  saudi arabian clothing unique men women wear c...       stereotype
# 3159  brahmin class people within hinduism well know...  anti-stereotype
# 3160  brahmin class people within hinduism three day...        unrelated
# 3161  brahmin class people within hinduism mostly kn...       stereotype
#
#           type
# 0         race
# 1         race
# 2         race
# 3         race
# 4         race
# ...        ...
# 3157      race
# 3158      race
# 3159  religion
# 3160  religion
# 3161  religion
#
# [3162 rows x 3 columns]

# %%
stemmer = PorterStemmer()
def stem_sentences(sentence):
    tokens = sentence.split()
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return ' '.join(stemmed_tokens)

# %%
df['sentences'] = df['sentences'].apply(stem_sentences) 
df
# Out:
#                                               sentences            label  \
# 0           mani peopl live ethiopia peopl fat unathlet  anti-stereotype
# 1     mani peopl live ethiopia peopl thin good dista...       stereotype
# 2               mani peopl live ethiopia cat sharp claw        unrelated
# 3                       professor hispan man came illeg       stereotype
# 4                    professor hispan man legal citizen  anti-stereotype
# ...                                                 ...              ...
# 3157        saudi arabian cloth uniqu eleph larg mammal        unrelated
# 3158     saudi arabian cloth uniqu men women wear cloth       stereotype
# 3159  brahmin class peopl within hinduism well known...  anti-stereotype
# 3160  brahmin class peopl within hinduism three day ...        unrelated
# 3161  brahmin class peopl within hinduism mostli kno...       stereotype
#
#           type
# 0         race
# 1         race
# 2         race
# 3         race
# 4         race
# ...        ...
# 3157      race
# 3158      race
# 3159  religion
# 3160  religion
# 3161  religion
#
# [3162 rows x 3 columns]

# %%
df_train, df_test = train_test_split(df, train_size=0.8, random_state=42)
print("TRAIN size:", len(df_train))
print("TEST size:", len(df_test))
# Out:
# TRAIN size: 2529
# TEST size: 633

# %%
documents = [_text.split() for _text in df_train.sentences]

# %%
model = gensim.models.Word2Vec(
        documents,
        vector_size=300,
        window=7,
        min_count=10,
        workers=10,
        epochs=10)

# %%
model.build_vocab(documents)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df_train.sentences)

vocab_size = len(tokenizer.word_index) + 1
print("Total words", vocab_size)
# Out:
# Total words 3164

# %%
x_train = pad_sequences(tokenizer.texts_to_sequences(df_train.sentences), maxlen=300)
x_test = pad_sequences(tokenizer.texts_to_sequences(df_test.sentences), maxlen=300)
